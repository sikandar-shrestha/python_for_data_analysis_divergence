# %% [markdown]
# # Project 3-3: Plot the exam data with Pandas
# ![Screenshot%202024-03-14%20at%2011.54.05%20PM.png](attachment:Screenshot%202024-03-14%20at%2011.54.05%20PM.png)

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd

# %% [markdown]
# ## Tasks

# %%
# 1 Read the data from the CSV file into a DataFrame and display the first five rows.
data = pd.read_csv('exams.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# 2 Use the pandas plot() method to create a box plot.
data.plot.box()
# Out:
# <Axes: >

# %%
# 3 Use the pandas plot() method to create a plot like the one that follows.
data.plot.scatter(x='math score', y='reading score')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
# 4 Group the data by the gender column and calculate the average scores. Then create a bar plot.
data.groupby('gender')[['math score','reading score','writing score']].mean().plot.bar()
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# ## Questions

# %%
# 1 What is the relationship between the reading score and the writing score?
data.plot.scatter(x='writing score', y='reading score')
# Out:
# <Axes: xlabel='writing score', ylabel='reading score'>

# %%
# 2 Does the type of lunch appear to have an effect on the average test scores?
data.groupby('lunch')[['math score','reading score','writing score']].mean().plot.bar()
# Out:
# <Axes: xlabel='lunch'>
